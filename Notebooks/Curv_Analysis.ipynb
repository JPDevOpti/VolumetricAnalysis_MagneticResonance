# %%
import pandas as pd

# Reemplaza 'ruta/a/tu/archivo.xlsx' con la ruta real de tu archivo
ruta_archivo_excel = '/home/jp/Repositorios/VolumetricAnalysis_MagneticResonance/Data/Demographic_data.csv'

# Lee la hoja específica del archivo Excel
df_demography = pd.read_csv(ruta_archivo_excel)
# Selecciona las primeras 60 filas (índices 0 a 59)
df_demography = df_demography[:61]
# Para verificar, puedes imprimir la forma (shape) del nuevo DataFrame
print(f"Dimensiones del DataFrame filtrado: {df_demography.shape}")
display(df_demography)
# Out:
# Dimensiones del DataFrame filtrado: (61, 7)
#        Code Biomarkers code   Birthdate Sex E280A group   MRI1 date  \
# 0   SAN_001         SAN_001  1995-07-26   F          GW  2023-04-14
# 1   SAN_003         SAN_003  1994-04-18   F          GK  2022-12-14
# 2   SAN_004         SAN_004  1990-08-29   M          GW  2023-01-10
# 3   SAN_005         SAN_005  1996-02-01   F          GK  2022-12-07
# 4   SAN_006         SAN_006  1990-07-25   F          GK  2023-01-28
# ..      ...             ...         ...  ..         ...         ...
# 56     S096         SAN_091  1981-12-24   F          GW  2023-07-05
# 57     S097         SAN_092  1980-03-17   F          GW  2023-07-05
# 58     S095         SAN_093  1978-09-10   F          GW  2023-07-04
# 59     S108         SAN_094  1980-09-07   F          GK  2023-07-19
# 60     S104         SAN_095  1983-10-16   F          GW  2023-07-14
#
#     Age at MRI
# 0    27.718001
# 1    28.657084
# 2    32.366872
# 3    26.847365
# 4    32.511978
# ..         ...
# 56   41.527721
# 57   43.299110
# 58   44.813142
# 59   42.861054
# 60   39.742642
#
# [61 rows x 7 columns]

# %%
import pandas as pd

# Cambia la ruta al archivo por la ubicación correcta si es necesario
df_area = pd.read_csv('/home/jp/Repositorios/VolumetricAnalysis_MagneticResonance/Data/lh_meancurv.txt', sep='\t')

# Opcional: ver las primeras filas para verificar la carga
display(df_area)
# Out:
#    lh.aparc.meancurv  lh_bankssts_meancurv  \
# 0        sub-SAN_001                 0.086
# 1        sub-SAN_003                 0.093
# 2        sub-SAN_004                 0.099
# 3        sub-SAN_005                 0.110
# 4        sub-SAN_006                 0.073
# ..               ...                   ...
# 56       sub-SAN_091                 0.097
# 57       sub-SAN_092                 0.086
# 58       sub-SAN_093                 0.080
# 59       sub-SAN_094                 0.086
# 60       sub-SAN_095                 0.109
#
#     lh_caudalanteriorcingulate_meancurv  lh_caudalmiddlefrontal_meancurv  \
# 0                                 0.134                            0.124
# 1                                 0.143                            0.116
# 2                                 0.174                            0.111
# 3                                 0.123                            0.107
# 4                                 0.119                            0.120
# ..                                  ...                              ...
# 56                                0.170                            0.110
# 57                                0.133                            0.117
# 58                                0.101                            0.116
# 59                                0.138                            0.119
# 60                                0.131                            0.107
#
#     lh_cuneus_meancurv  lh_entorhinal_meancurv  lh_fusiform_meancurv  \
# 0                0.135                   0.106                 0.120
# 1                0.156                   0.118                 0.129
# 2                0.141                   0.105                 0.124
# 3                0.146                   0.089                 0.120
# 4                0.137                   0.117                 0.128
# ..                 ...                     ...                   ...
# 56               0.134                   0.093                 0.127
# 57               0.124                   0.127                 0.138
# 58               0.128                   0.104                 0.110
# 59               0.133                   0.099                 0.130
# 60               0.141                   0.108                 0.124
#
#     lh_inferiorparietal_meancurv  lh_inferiortemporal_meancurv  \
# 0                          0.126                         0.119
# 1                          0.124                         0.131
# 2                          0.116                         0.117
# 3                          0.115                         0.117
# 4                          0.124                         0.117
# ..                           ...                           ...
# 56                         0.129                         0.138
# 57                         0.126                         0.130
# 58                         0.113                         0.131
# 59                         0.114                         0.124
# 60                         0.125                         0.125
#
#     lh_isthmuscingulate_meancurv  ...  lh_superiorfrontal_meancurv  \
# 0                          0.114  ...                        0.117
# 1                          0.107  ...                        0.125
# 2                          0.126  ...                        0.111
# 3                          0.117  ...                        0.113
# 4                          0.112  ...                        0.119
# ..                           ...  ...                          ...
# 56                         0.119  ...                        0.124
# 57                         0.117  ...                        0.115
# 58                         0.133  ...                        0.109
# 59                         0.111  ...                        0.113
# 60                         0.125  ...                        0.111
#
#     lh_superiorparietal_meancurv  lh_superiortemporal_meancurv  \
# 0                          0.112                         0.105
# 1                          0.123                         0.108
# 2                          0.113                         0.102
# 3                          0.113                         0.102
# 4                          0.127                         0.099
# ..                           ...                           ...
# 56                         0.114                         0.093
# 57                         0.111                         0.126
# 58                         0.117                         0.096
# 59                         0.114                         0.098
# 60                         0.121                         0.101
#
#     lh_supramarginal_meancurv  lh_frontalpole_meancurv  \
# 0                       0.119                    0.151
# 1                       0.127                    0.183
# 2                       0.123                    0.167
# 3                       0.120                    0.191
# 4                       0.120                    0.176
# ..                        ...                      ...
# 56                      0.136                    0.179
# 57                      0.129                    0.158
# 58                      0.120                    0.136
# 59                      0.124                    0.169
# 60                      0.126                    0.179
#
#     lh_temporalpole_meancurv  lh_transversetemporal_meancurv  \
# 0                      0.153                           0.125
# 1                      0.139                           0.131
# 2                      0.141                           0.106
# 3                      0.145                           0.114
# 4                      0.170                           0.125
# ..                       ...                             ...
# 56                     0.134                           0.121
# 57                     0.141                           0.107
# 58                     0.158                           0.133
# 59                     0.147                           0.113
# 60                     0.129                           0.088
#
#     lh_insula_meancurv  BrainSegVolNotVent          eTIV
# 0                0.091           1090732.0  1.010279e+06
# 1                0.122           1088990.0  9.928702e+05
# 2                0.104           1218335.0  1.137339e+06
# 3                0.118            997606.0  1.394186e+06
# 4                0.103           1074106.0  1.001934e+06
# ..                 ...                 ...           ...
# 56               0.098            990041.0  9.347594e+05
# 57               0.111            995584.0  9.294549e+05
# 58               0.115           1054842.0  9.870775e+05
# 59               0.112            903886.0  8.312529e+05
# 60               0.112            917980.0  8.472996e+05
#
# [61 rows x 37 columns]

# %%
import pandas as pd

# 1. Carga los archivos
df_demo = pd.read_csv('/home/jp/Repositorios/VolumetricAnalysis_MagneticResonance/Data/Demographic_data.csv')
df_lh = pd.read_csv('/home/jp/Repositorios/VolumetricAnalysis_MagneticResonance/Data/lh_meancurv.txt', sep='\t')
df_rh = pd.read_csv('/home/jp/Repositorios/VolumetricAnalysis_MagneticResonance/Data/rh_meancurv.txt', sep='\t')

# Renombrar la columna de identificación en los archivos de áreas
df_lh = df_lh.rename(columns={df_lh.columns[0]: 'Biomarkers code'})
df_lh['Biomarkers code'] = df_lh['Biomarkers code'].str.replace('sub-', '', regex=False)

df_rh = df_rh.rename(columns={df_rh.columns[0]: 'Biomarkers code'})
df_rh['Biomarkers code'] = df_rh['Biomarkers code'].str.replace('sub-', '', regex=False)

# --- Solución al problema de duplicados ---
# Si existen tanto 'Code' como 'Biomarkers code' en df_demo, eliminamos 'Code' tras renombrar
if 'Code' in df_demo.columns and 'Biomarkers code' in df_demo.columns:
    df_demo = df_demo.drop(columns=['Code'])

# Si solo existe 'Code', la renombramos
elif 'Code' in df_demo.columns:
    df_demo = df_demo.rename(columns={'Code': 'Biomarkers code'})

# Si solo existe 'Biomarkers code', no hacemos nada

# Nos aseguramos de que solo hay UNA columna 'Biomarkers code'
df_demo = df_demo.loc[:,~df_demo.columns.duplicated()]

# Realiza el primer merge
df_merged = pd.merge(df_demo, df_lh, on='Biomarkers code', how='inner')

# Realiza el segundo merge
df_merged = pd.merge(df_merged, df_rh, on='Biomarkers code', how='inner', suffixes=('_lh', '_rh'))

# Elimina columnas innecesarias (ajusta la lista según lo que desees eliminar)
cols_to_drop = ['BrainSegVolNotVent_lh', 'BrainSegVolNotVent_rh', 'eTIV_lh', 'eTIV_rh']
df_merged = df_merged.drop(columns=[col for col in cols_to_drop if col in df_merged.columns], errors='ignore')

# Lista de columnas a eliminar
cols_to_drop = ['Birthdate', 'Sex', 'MRI1 date', 'Age at MRI']

# Elimina las columnas (si existen)
df_merged = df_merged.drop(columns=cols_to_drop, errors='ignore')

display(df_merged)
# Out:
#    Biomarkers code E280A group  lh_bankssts_meancurv  \
# 0          SAN_001          GW                 0.086
# 1          SAN_003          GK                 0.093
# 2          SAN_004          GW                 0.099
# 3          SAN_005          GK                 0.110
# 4          SAN_006          GK                 0.073
# ..             ...         ...                   ...
# 56         SAN_091          GW                 0.097
# 57         SAN_092          GW                 0.086
# 58         SAN_093          GW                 0.080
# 59         SAN_094          GK                 0.086
# 60         SAN_095          GW                 0.109
#
#     lh_caudalanteriorcingulate_meancurv  lh_caudalmiddlefrontal_meancurv  \
# 0                                 0.134                            0.124
# 1                                 0.143                            0.116
# 2                                 0.174                            0.111
# 3                                 0.123                            0.107
# 4                                 0.119                            0.120
# ..                                  ...                              ...
# 56                                0.170                            0.110
# 57                                0.133                            0.117
# 58                                0.101                            0.116
# 59                                0.138                            0.119
# 60                                0.131                            0.107
#
#     lh_cuneus_meancurv  lh_entorhinal_meancurv  lh_fusiform_meancurv  \
# 0                0.135                   0.106                 0.120
# 1                0.156                   0.118                 0.129
# 2                0.141                   0.105                 0.124
# 3                0.146                   0.089                 0.120
# 4                0.137                   0.117                 0.128
# ..                 ...                     ...                   ...
# 56               0.134                   0.093                 0.127
# 57               0.124                   0.127                 0.138
# 58               0.128                   0.104                 0.110
# 59               0.133                   0.099                 0.130
# 60               0.141                   0.108                 0.124
#
#     lh_inferiorparietal_meancurv  lh_inferiortemporal_meancurv  ...  \
# 0                          0.126                         0.119  ...
# 1                          0.124                         0.131  ...
# 2                          0.116                         0.117  ...
# 3                          0.115                         0.117  ...
# 4                          0.124                         0.117  ...
# ..                           ...                           ...  ...
# 56                         0.129                         0.138  ...
# 57                         0.126                         0.130  ...
# 58                         0.113                         0.131  ...
# 59                         0.114                         0.124  ...
# 60                         0.125                         0.125  ...
#
#     rh_rostralanteriorcingulate_meancurv  rh_rostralmiddlefrontal_meancurv  \
# 0                                  0.121                             0.122
# 1                                  0.112                             0.149
# 2                                  0.108                             0.122
# 3                                  0.139                             0.136
# 4                                  0.116                             0.138
# ..                                   ...                               ...
# 56                                 0.139                             0.142
# 57                                 0.113                             0.127
# 58                                 0.130                             0.124
# 59                                 0.112                             0.132
# 60                                 0.120                             0.143
#
#     rh_superiorfrontal_meancurv  rh_superiorparietal_meancurv  \
# 0                         0.116                         0.112
# 1                         0.128                         0.119
# 2                         0.116                         0.114
# 3                         0.114                         0.121
# 4                         0.116                         0.105
# ..                          ...                           ...
# 56                        0.125                         0.127
# 57                        0.115                         0.111
# 58                        0.107                         0.115
# 59                        0.124                         0.117
# 60                        0.116                         0.114
#
#     rh_superiortemporal_meancurv  rh_supramarginal_meancurv  \
# 0                          0.100                      0.110
# 1                          0.107                      0.126
# 2                          0.108                      0.116
# 3                          0.102                      0.126
# 4                          0.097                      0.112
# ..                           ...                        ...
# 56                         0.102                      0.124
# 57                         0.119                      0.132
# 58                         0.095                      0.112
# 59                         0.090                      0.113
# 60                         0.095                      0.118
#
#     rh_frontalpole_meancurv  rh_temporalpole_meancurv  \
# 0                     0.150                     0.158
# 1                     0.171                     0.137
# 2                     0.178                     0.157
# 3                     0.169                     0.126
# 4                     0.175                     0.135
# ..                      ...                       ...
# 56                    0.173                     0.127
# 57                    0.165                     0.137
# 58                    0.161                     0.164
# 59                    0.171                     0.117
# 60                    0.171                     0.155
#
#     rh_transversetemporal_meancurv  rh_insula_meancurv
# 0                            0.131               0.089
# 1                            0.122               0.127
# 2                            0.127               0.104
# 3                            0.117               0.108
# 4                            0.119               0.103
# ..                             ...                 ...
# 56                           0.106               0.106
# 57                           0.120               0.108
# 58                           0.092               0.091
# 59                           0.128               0.107
# 60                           0.127               0.122
#
# [61 rows x 70 columns]

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns

# Asegúrate de tener seaborn y matplotlib instalados:
# !pip install seaborn matplotlib

# Identifica las columnas de regiones cerebrales
# (asumiendo que las primeras columnas son identificadores y grupo)
# Ajusta el índice si tus columnas de regiones empiezan después de la columna 'E280A group'
region_columns = df_merged.columns[1:]  # Si la primera es 'Biomarkers code', y la segunda es 'E280A group'
if 'E280A group' in df_merged.columns:
    region_columns = df_merged.columns[df_merged.columns.get_loc('E280A group')+1:]

# Crea carpetas para guardar los gráficos
os.makedirs("plots/bar", exist_ok=True)
os.makedirs("plots/box", exist_ok=True)
os.makedirs("plots/violin", exist_ok=True)

for region in region_columns:
    plt.figure(figsize=(8,5))
    # Diagrama de barras
    sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
    plt.title(f'Diagrama de barras - {region}')
    plt.tight_layout()
    plt.savefig(f"plots/bar/bar_{region}.png")
    plt.close()

    # Caja y bigotes
    plt.figure(figsize=(8,5))
    sns.boxplot(data=df_merged, x='E280A group', y=region)
    plt.title(f'Boxplot - {region}')
    plt.tight_layout()
    plt.savefig(f"plots/box/box_{region}.png")
    plt.close()

    # Violin plot
    plt.figure(figsize=(8,5))
    sns.violinplot(data=df_merged, x='E280A group', y=region, inner='box')
    plt.title(f'Violin plot - {region}')
    plt.tight_layout()
    plt.savefig(f"plots/violin/violin_{region}.png")
    plt.close()
# Out:
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_16907/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Identifica las columnas de regiones cerebrales
if 'E280A group' in df_merged.columns:
    region_columns = df_merged.columns[df_merged.columns.get_loc('E280A group')+1:]
else:
    # Si no encuentras la columna, ajusta el índice manualmente
    region_columns = df_merged.columns[2:]

# Transforma el DataFrame a formato largo
df_long = pd.melt(
    df_merged,
    id_vars=['Biomarkers code', 'E280A group'],
    value_vars=region_columns,
    var_name='Región cerebral',
    value_name='Curvatura'
)

# Gráfico de barras agrupado por región y grupo
plt.figure(figsize=(18, 7))
sns.barplot(
    data=df_long,
    x='Región cerebral',
    y='Curvatura',
    hue='E280A group',
    ci='sd'
)
plt.xticks(rotation=90)
plt.title('Comparación de Curvatura por región cerebral y grupo')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_27791/1368113947.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(

# %%
import pandas as pd
from scipy.stats import ttest_ind, shapiro, mannwhitneyu

# Identifica las columnas de regiones cerebrales
if 'E280A group' in df_merged.columns:
    region_columns = df_merged.columns[df_merged.columns.get_loc('E280A group')+1:]
else:
    region_columns = df_merged.columns[2:]

group_col = 'E280A group'
groups = df_merged[group_col].unique()

results = []

for region in region_columns:
    data1 = df_merged[df_merged[group_col] == groups[0]][region].dropna()
    data2 = df_merged[df_merged[group_col] == groups[1]][region].dropna()
    shapiro_p1 = shapiro(data1).pvalue if len(data1) >= 3 else None
    shapiro_p2 = shapiro(data2).pvalue if len(data2) >= 3 else None
    both_normal = (
        shapiro_p1 is not None and shapiro_p2 is not None and
        shapiro_p1 > 0.05 and shapiro_p2 > 0.05
    )
    if both_normal:
        test = "t-test"
        stat, p_val = ttest_ind(data1, data2)
    else:
        test = "Mann-Whitney U"
        if len(data1) >= 3 and len(data2) >= 3:
            stat, p_val = mannwhitneyu(data1, data2, alternative='two-sided')
        else:
            p_val = None
    significant = p_val is not None and p_val < 0.1
    results.append({
        'Region': region,
        f'Shapiro p ({groups[0]})': shapiro_p1,
        f'Shapiro p ({groups[1]})': shapiro_p2,
        f'Mean ({groups[0]})': data1.mean() if len(data1) > 0 else None,
        f'Mean ({groups[1]})': data2.mean() if len(data2) > 0 else None,
        'Test used': test,
        'p-value': p_val,
        'Statistically significant': significant
    })

comparison_table = pd.DataFrame(results)
comparison_table.to_csv("brain_regions_group_comparison.csv", index=False)
print("Table saved as brain_regions_group_comparison.csv")
display(comparison_table)
# Out:
# Table saved as brain_regions_group_comparison.csv
#                                  Region  Shapiro p (GW)  Shapiro p (GK)  \
# 0                  lh_bankssts_meancurv        0.629316        0.901129
# 1   lh_caudalanteriorcingulate_meancurv        0.163058        0.761709
# 2       lh_caudalmiddlefrontal_meancurv        0.130512        0.500188
# 3                    lh_cuneus_meancurv        0.691960        0.268403
# 4                lh_entorhinal_meancurv        0.639992        0.651578
# ..                                  ...             ...             ...
# 63            rh_supramarginal_meancurv        0.593104        0.012933
# 64              rh_frontalpole_meancurv        0.481797        0.271793
# 65             rh_temporalpole_meancurv        0.422705        0.584471
# 66       rh_transversetemporal_meancurv        0.900908        0.952332
# 67                   rh_insula_meancurv        0.510716        0.133107
#
#     Mean (GW)  Mean (GK)       Test used   p-value  Statistically significant
# 0    0.093833    0.09380          t-test  0.990691                      False
# 1    0.124000    0.12308          t-test  0.839143                      False
# 2    0.113000    0.11328          t-test  0.880449                      False
# 3    0.141833    0.13720          t-test  0.091378                       True
# 4    0.100278    0.10092          t-test  0.809014                      False
# ..        ...        ...             ...       ...                        ...
# 63   0.119778    0.11896  Mann-Whitney U  0.436258                      False
# 64   0.166778    0.16540          t-test  0.736125                      False
# 65   0.147250    0.13844          t-test  0.024271                       True
# 66   0.113472    0.11780          t-test  0.285472                      False
# 67   0.107111    0.10664          t-test  0.803146                      False
#
# [68 rows x 8 columns]

# %%
# Assuming you already have 'comparison_table' from your previous code

# Filter only statistically significant regions
significant_table = comparison_table[comparison_table['Statistically significant'] == True].copy()

# Optionally, reset the index for a clean table
significant_table = significant_table.reset_index(drop=True)

# Save to CSV
significant_table.to_csv("brain_regions_significant_comparison.csv", index=False)
print("Table saved as brain_regions_significant_comparison.csv")

# Display the table in the notebook
display(significant_table)
# Out:
# Table saved as brain_regions_significant_comparison.csv
#                                  Region  Shapiro p (GW)  Shapiro p (GK)  \
# 0                    lh_cuneus_meancurv        0.691960        0.268403
# 1          lh_isthmuscingulate_meancurv        0.006625        0.014487
# 2           lh_parsopercularis_meancurv        0.536126        0.231557
# 3          lh_parstriangularis_meancurv        0.213366        0.082237
# 4             lh_pericalcarine_meancurv        0.005502        0.048925
# 5                lh_precentral_meancurv        0.253531        0.008191
# 6          rh_isthmuscingulate_meancurv        0.727728        0.364375
# 7  rh_rostralanteriorcingulate_meancurv        0.631218        0.297101
# 8              rh_temporalpole_meancurv        0.422705        0.584471
#
#    Mean (GW)  Mean (GK)       Test used   p-value  Statistically significant
# 0   0.141833    0.13720          t-test  0.091378                       True
# 1   0.121306    0.11716  Mann-Whitney U  0.036978                       True
# 2   0.114861    0.11120          t-test  0.080775                       True
# 3   0.117083    0.12208          t-test  0.039012                       True
# 4   0.141028    0.13488  Mann-Whitney U  0.057326                       True
# 5   0.103417    0.10148  Mann-Whitney U  0.051102                       True
# 6   0.124861    0.11716          t-test  0.004860                       True
# 7   0.122944    0.12992          t-test  0.053406                       True
# 8   0.147250    0.13844          t-test  0.024271                       True

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Lista de regiones significativas
significant_regions = comparison_table[comparison_table['Statistically significant'] == True]['Region'].tolist()

if significant_regions:
    # 2. Transforma df_merged a formato largo solo con regiones significativas
    df_long = df_merged.melt(
        id_vars=['Biomarkers code', 'E280A group'],
        value_vars=significant_regions,
        var_name='Brain Region',
        value_name='Curvature'
    )

    # 3. Gráfico de barras solo para regiones significativas
    plt.figure(figsize=(max(8, len(significant_regions)*1.2), 6))
    sns.barplot(
        data=df_long,
        x='Brain Region',
        y='Curvature',
        hue='E280A group',
        ci='sd'
    )
    plt.title('Group Comparison for Significant Brain Regions')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()
else:
    print("No se encontraron regiones con diferencias significativas (p < 0.01).")
# Out:
# /tmp/ipykernel_16907/1653910943.py:18: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(
