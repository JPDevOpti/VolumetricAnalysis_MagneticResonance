# %%
import pandas as pd

# Reemplaza 'ruta/a/tu/archivo.xlsx' con la ruta real de tu archivo
ruta_archivo_excel = '/home/jp/Repositorios/VolumetricAnalysis_MagneticResonance/Data/Demographic_data.csv'

# Lee la hoja específica del archivo Excel
df_demography = pd.read_csv(ruta_archivo_excel)
# Selecciona las primeras 60 filas (índices 0 a 59)
df_demography = df_demography[:61]
# Para verificar, puedes imprimir la forma (shape) del nuevo DataFrame
print(f"Dimensiones del DataFrame filtrado: {df_demography.shape}")
display(df_demography)
# Out:
# Dimensiones del DataFrame filtrado: (61, 7)
#        Code Biomarkers code   Birthdate Sex E280A group   MRI1 date  \
# 0   SAN_001         SAN_001  1995-07-26   F          GW  2023-04-14
# 1   SAN_003         SAN_003  1994-04-18   F          GK  2022-12-14
# 2   SAN_004         SAN_004  1990-08-29   M          GW  2023-01-10
# 3   SAN_005         SAN_005  1996-02-01   F          GK  2022-12-07
# 4   SAN_006         SAN_006  1990-07-25   F          GK  2023-01-28
# ..      ...             ...         ...  ..         ...         ...
# 56     S096         SAN_091  1981-12-24   F          GW  2023-07-05
# 57     S097         SAN_092  1980-03-17   F          GW  2023-07-05
# 58     S095         SAN_093  1978-09-10   F          GW  2023-07-04
# 59     S108         SAN_094  1980-09-07   F          GK  2023-07-19
# 60     S104         SAN_095  1983-10-16   F          GW  2023-07-14
#
#     Age at MRI
# 0    27.718001
# 1    28.657084
# 2    32.366872
# 3    26.847365
# 4    32.511978
# ..         ...
# 56   41.527721
# 57   43.299110
# 58   44.813142
# 59   42.861054
# 60   39.742642
#
# [61 rows x 7 columns]

# %%
import pandas as pd

# Cambia la ruta al archivo por la ubicación correcta si es necesario
df_area = pd.read_csv('/home/jp/Repositorios/VolumetricAnalysis_MagneticResonance/Data/lh.area.txt', sep='\t')

# Opcional: ver las primeras filas para verificar la carga
display(df_area)
# Out:
#    lh.aparc.area  lh_bankssts_area  lh_caudalanteriorcingulate_area  \
# 0    sub-SAN_001             776.0                            664.0
# 1    sub-SAN_003             860.0                            732.0
# 2    sub-SAN_004             894.0                            665.0
# 3    sub-SAN_005             883.0                            532.0
# 4    sub-SAN_006             826.0                            547.0
# ..           ...               ...                              ...
# 56   sub-SAN_091             962.0                            593.0
# 57   sub-SAN_092             716.0                            585.0
# 58   sub-SAN_093             796.0                            504.0
# 59   sub-SAN_094             674.0                            465.0
# 60   sub-SAN_095             717.0                            379.0
#
#     lh_caudalmiddlefrontal_area  lh_cuneus_area  lh_entorhinal_area  \
# 0                        1826.0          1650.0               408.0
# 1                        1897.0          1687.0               436.0
# 2                        2243.0          1542.0               433.0
# 3                        2065.0          1324.0               464.0
# 4                        2151.0          1663.0               349.0
# ..                          ...             ...                 ...
# 56                       1654.0          1453.0               261.0
# 57                       1798.0          1321.0               431.0
# 58                       1920.0          1403.0               320.0
# 59                       1481.0          1326.0               379.0
# 60                       1690.0          1515.0               325.0
#
#     lh_fusiform_area  lh_inferiorparietal_area  lh_inferiortemporal_area  \
# 0             2709.0                    4255.0                    3237.0
# 1             2883.0                    4662.0                    3313.0
# 2             3005.0                    4744.0                    3707.0
# 3             2615.0                    4366.0                    3015.0
# 4             2729.0                    3733.0                    2862.0
# ..               ...                       ...                       ...
# 56            2619.0                    4739.0                    2648.0
# 57            2620.0                    3468.0                    2726.0
# 58            2581.0                    4086.0                    3227.0
# 59            2202.0                    3092.0                    2574.0
# 60            3040.0                    3563.0                    2341.0
#
#     lh_isthmuscingulate_area  ...  lh_superiorparietal_area  \
# 0                      934.0  ...                    5670.0
# 1                      893.0  ...                    5627.0
# 2                     1478.0  ...                    5525.0
# 3                      852.0  ...                    5311.0
# 4                      874.0  ...                    4936.0
# ..                       ...  ...                       ...
# 56                    1009.0  ...                    4650.0
# 57                     821.0  ...                    5464.0
# 58                     965.0  ...                    5413.0
# 59                     699.0  ...                    3851.0
# 60                     870.0  ...                    4306.0
#
#     lh_superiortemporal_area  lh_supramarginal_area  lh_frontalpole_area  \
# 0                     3368.0                 4363.0                276.0
# 1                     3288.0                 3382.0                269.0
# 2                     3968.0                 4238.0                296.0
# 3                     3553.0                 3872.0                283.0
# 4                     3544.0                 3367.0                257.0
# ..                       ...                    ...                  ...
# 56                    3064.0                 3128.0                220.0
# 57                    3078.0                 3704.0                229.0
# 58                    3514.0                 3692.0                229.0
# 59                    2844.0                 2395.0                240.0
# 60                    3278.0                 3646.0                229.0
#
#     lh_temporalpole_area  lh_transversetemporal_area  lh_insula_area  \
# 0                  489.0                       457.0          1873.0
# 1                  587.0                       374.0          2056.0
# 2                  647.0                       510.0          2416.0
# 3                  399.0                       428.0          2029.0
# 4                  526.0                       387.0          1940.0
# ..                   ...                         ...             ...
# 56                 461.0                       345.0          1721.0
# 57                 419.0                       367.0          1955.0
# 58                 498.0                       372.0          2268.0
# 59                 441.0                       309.0          1826.0
# 60                 396.0                       415.0          1774.0
#
#     lh_WhiteSurfArea_area  BrainSegVolNotVent          eTIV
# 0                 79300.6           1096432.0  1.584823e+06
# 1                 80784.7           1088990.0  9.928702e+05
# 2                 86119.6           1218335.0  1.137339e+06
# 3                 74570.5            997606.0  1.394186e+06
# 4                 78117.2           1074106.0  1.001934e+06
# ..                    ...                 ...           ...
# 56                72882.2            990041.0  9.347594e+05
# 57                70668.9            995584.0  9.294549e+05
# 58                76330.0           1054842.0  9.870775e+05
# 59                63402.8            903886.0  8.312529e+05
# 60                68752.4            917980.0  8.472996e+05
#
# [61 rows x 38 columns]

# %%
import pandas as pd

# 1. Carga los archivos
df_demo = pd.read_csv('/home/jp/Repositorios/VolumetricAnalysis_MagneticResonance/Data/Demographic_data.csv')
df_lh = pd.read_csv('/home/jp/Repositorios/VolumetricAnalysis_MagneticResonance/Data/lh.area.txt', sep='\t')
df_rh = pd.read_csv('/home/jp/Repositorios/VolumetricAnalysis_MagneticResonance/Data/rh.area.txt', sep='\t')

# Renombrar la columna de identificación en los archivos de áreas
df_lh = df_lh.rename(columns={df_lh.columns[0]: 'Biomarkers code'})
df_lh['Biomarkers code'] = df_lh['Biomarkers code'].str.replace('sub-', '', regex=False)

df_rh = df_rh.rename(columns={df_rh.columns[0]: 'Biomarkers code'})
df_rh['Biomarkers code'] = df_rh['Biomarkers code'].str.replace('sub-', '', regex=False)

# --- Solución al problema de duplicados ---
# Si existen tanto 'Code' como 'Biomarkers code' en df_demo, eliminamos 'Code' tras renombrar
if 'Code' in df_demo.columns and 'Biomarkers code' in df_demo.columns:
    df_demo = df_demo.drop(columns=['Code'])

# Si solo existe 'Code', la renombramos
elif 'Code' in df_demo.columns:
    df_demo = df_demo.rename(columns={'Code': 'Biomarkers code'})

# Si solo existe 'Biomarkers code', no hacemos nada

# Nos aseguramos de que solo hay UNA columna 'Biomarkers code'
df_demo = df_demo.loc[:,~df_demo.columns.duplicated()]

# Realiza el primer merge
df_merged = pd.merge(df_demo, df_lh, on='Biomarkers code', how='inner')

# Realiza el segundo merge
df_merged = pd.merge(df_merged, df_rh, on='Biomarkers code', how='inner', suffixes=('_lh', '_rh'))

# Elimina columnas innecesarias (ajusta la lista según lo que desees eliminar)
cols_to_drop = ['BrainSegVolNotVent_lh', 'BrainSegVolNotVent_rh', 'eTIV_lh', 'eTIV_rh']
df_merged = df_merged.drop(columns=[col for col in cols_to_drop if col in df_merged.columns], errors='ignore')

# Lista de columnas a eliminar
cols_to_drop = ['Birthdate', 'Sex', 'MRI1 date', 'Age at MRI']

# Elimina las columnas (si existen)
df_merged = df_merged.drop(columns=cols_to_drop, errors='ignore')

display(df_merged)
# Out:
#    Biomarkers code E280A group  lh_bankssts_area  \
# 0          SAN_001          GW             776.0
# 1          SAN_003          GK             860.0
# 2          SAN_004          GW             894.0
# 3          SAN_005          GK             883.0
# 4          SAN_006          GK             826.0
# ..             ...         ...               ...
# 56         SAN_091          GW             962.0
# 57         SAN_092          GW             716.0
# 58         SAN_093          GW             796.0
# 59         SAN_094          GK             674.0
# 60         SAN_095          GW             717.0
#
#     lh_caudalanteriorcingulate_area  lh_caudalmiddlefrontal_area  \
# 0                             664.0                       1826.0
# 1                             732.0                       1897.0
# 2                             665.0                       2243.0
# 3                             532.0                       2065.0
# 4                             547.0                       2151.0
# ..                              ...                          ...
# 56                            593.0                       1654.0
# 57                            585.0                       1798.0
# 58                            504.0                       1920.0
# 59                            465.0                       1481.0
# 60                            379.0                       1690.0
#
#     lh_cuneus_area  lh_entorhinal_area  lh_fusiform_area  \
# 0           1650.0               408.0            2709.0
# 1           1687.0               436.0            2883.0
# 2           1542.0               433.0            3005.0
# 3           1324.0               464.0            2615.0
# 4           1663.0               349.0            2729.0
# ..             ...                 ...               ...
# 56          1453.0               261.0            2619.0
# 57          1321.0               431.0            2620.0
# 58          1403.0               320.0            2581.0
# 59          1326.0               379.0            2202.0
# 60          1515.0               325.0            3040.0
#
#     lh_inferiorparietal_area  lh_inferiortemporal_area  ...  \
# 0                     4255.0                    3237.0  ...
# 1                     4662.0                    3313.0  ...
# 2                     4744.0                    3707.0  ...
# 3                     4366.0                    3015.0  ...
# 4                     3733.0                    2862.0  ...
# ..                       ...                       ...  ...
# 56                    4739.0                    2648.0  ...
# 57                    3468.0                    2726.0  ...
# 58                    4086.0                    3227.0  ...
# 59                    3092.0                    2574.0  ...
# 60                    3563.0                    2341.0  ...
#
#     rh_rostralmiddlefrontal_area  rh_superiorfrontal_area  \
# 0                         4777.0                   6189.0
# 1                         4908.0                   6734.0
# 2                         5229.0                   6743.0
# 3                         5069.0                   5586.0
# 4                         5281.0                   5852.0
# ..                           ...                      ...
# 56                        4743.0                   5636.0
# 57                        4428.0                   5915.0
# 58                        5458.0                   6027.0
# 59                        3723.0                   4943.0
# 60                        4137.0                   5608.0
#
#     rh_superiorparietal_area  rh_superiortemporal_area  rh_supramarginal_area  \
# 0                     5622.0                    3401.0                 3301.0
# 1                     4626.0                    3183.0                 3711.0
# 2                     5205.0                    3790.0                 4061.0
# 3                     4952.0                    3404.0                 3154.0
# 4                     4559.0                    3576.0                 3518.0
# ..                       ...                       ...                    ...
# 56                    4508.0                    3008.0                 3145.0
# 57                    5028.0                    3024.0                 2958.0
# 58                    4945.0                    3362.0                 3806.0
# 59                    3743.0                    2780.0                 2532.0
# 60                    4129.0                    3025.0                 2899.0
#
#     rh_frontalpole_area  rh_temporalpole_area  rh_transversetemporal_area  \
# 0                 286.0                 492.0                       343.0
# 1                 332.0                 502.0                       275.0
# 2                 353.0                 586.0                       308.0
# 3                 320.0                 404.0                       282.0
# 4                 417.0                 442.0                       333.0
# ..                  ...                   ...                         ...
# 56                327.0                 489.0                       255.0
# 57                284.0                 372.0                       296.0
# 58                343.0                 532.0                       289.0
# 59                265.0                 401.0                       220.0
# 60                290.0                 413.0                       249.0
#
#     rh_insula_area  rh_WhiteSurfArea_area
# 0           2022.0                78439.1
# 1           2008.0                79722.8
# 2           2158.0                85896.3
# 3           1965.0                74937.9
# 4           1905.0                79631.6
# ..             ...                    ...
# 56          1837.0                74085.7
# 57          1841.0                71983.2
# 58          1847.0                77233.9
# 59          1784.0                64070.1
# 60          2078.0                69128.4
#
# [61 rows x 72 columns]

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns

# Asegúrate de tener seaborn y matplotlib instalados:
# !pip install seaborn matplotlib

# Identifica las columnas de regiones cerebrales
# (asumiendo que las primeras columnas son identificadores y grupo)
# Ajusta el índice si tus columnas de regiones empiezan después de la columna 'E280A group'
region_columns = df_merged.columns[1:]  # Si la primera es 'Biomarkers code', y la segunda es 'E280A group'
if 'E280A group' in df_merged.columns:
    region_columns = df_merged.columns[df_merged.columns.get_loc('E280A group')+1:]

# Crea carpetas para guardar los gráficos
os.makedirs("plots/bar", exist_ok=True)
os.makedirs("plots/box", exist_ok=True)
os.makedirs("plots/violin", exist_ok=True)

for region in region_columns:
    plt.figure(figsize=(8,5))
    # Diagrama de barras
    sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
    plt.title(f'Diagrama de barras - {region}')
    plt.tight_layout()
    plt.savefig(f"plots/bar/bar_{region}.png")
    plt.close()

    # Caja y bigotes
    plt.figure(figsize=(8,5))
    sns.boxplot(data=df_merged, x='E280A group', y=region)
    plt.title(f'Boxplot - {region}')
    plt.tight_layout()
    plt.savefig(f"plots/box/box_{region}.png")
    plt.close()

    # Violin plot
    plt.figure(figsize=(8,5))
    sns.violinplot(data=df_merged, x='E280A group', y=region, inner='box')
    plt.title(f'Violin plot - {region}')
    plt.tight_layout()
    plt.savefig(f"plots/violin/violin_{region}.png")
    plt.close()
# Out:
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')
# /tmp/ipykernel_8177/2557724410.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=df_merged, x='E280A group', y=region, ci='sd')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Identifica las columnas de regiones cerebrales
if 'E280A group' in df_merged.columns:
    region_columns = df_merged.columns[df_merged.columns.get_loc('E280A group')+1:]
else:
    # Si no encuentras la columna, ajusta el índice manualmente
    region_columns = df_merged.columns[2:]

# Transforma el DataFrame a formato largo
df_long = pd.melt(
    df_merged,
    id_vars=['Biomarkers code', 'E280A group'],
    value_vars=region_columns,
    var_name='Región cerebral',
    value_name='Volumen'
)

# Gráfico de barras agrupado por región y grupo
plt.figure(figsize=(18, 7))
sns.barplot(
    data=df_long,
    x='Región cerebral',
    y='Volumen',
    hue='E280A group',
    ci='sd'
)
plt.xticks(rotation=90)
plt.title('Comparación de volúmenes por región cerebral y grupo')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_26032/125923223.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(

# %%
import pandas as pd
from scipy.stats import ttest_ind, shapiro, mannwhitneyu

# Identifica las columnas de regiones cerebrales
if 'E280A group' in df_merged.columns:
    region_columns = df_merged.columns[df_merged.columns.get_loc('E280A group')+1:]
else:
    region_columns = df_merged.columns[2:]

group_col = 'E280A group'
groups = df_merged[group_col].unique()

results = []

for region in region_columns:
    data1 = df_merged[df_merged[group_col] == groups[0]][region].dropna()
    data2 = df_merged[df_merged[group_col] == groups[1]][region].dropna()
    shapiro_p1 = shapiro(data1).pvalue if len(data1) >= 3 else None
    shapiro_p2 = shapiro(data2).pvalue if len(data2) >= 3 else None
    both_normal = (
        shapiro_p1 is not None and shapiro_p2 is not None and
        shapiro_p1 > 0.05 and shapiro_p2 > 0.05
    )
    if both_normal:
        test = "t-test"
        stat, p_val = ttest_ind(data1, data2)
    else:
        test = "Mann-Whitney U"
        if len(data1) >= 3 and len(data2) >= 3:
            stat, p_val = mannwhitneyu(data1, data2, alternative='two-sided')
        else:
            p_val = None
    significant = p_val is not None and p_val < 0.1
    results.append({
        'Region': region,
        f'Shapiro p ({groups[0]})': shapiro_p1,
        f'Shapiro p ({groups[1]})': shapiro_p2,
        'Test used': test,
        'p-value': p_val,
        'Statistically significant': significant
    })

comparison_table = pd.DataFrame(results)
comparison_table.to_csv("brain_regions_group_comparison.csv", index=False)
print("Table saved as brain_regions_group_comparison.csv")
display(comparison_table)
# Out:
# Table saved as brain_regions_group_comparison.csv
#                              Region  Shapiro p (GW)  Shapiro p (GK)  \
# 0                  lh_bankssts_area        0.006796        0.688539
# 1   lh_caudalanteriorcingulate_area        0.678424        0.549566
# 2       lh_caudalmiddlefrontal_area        0.094907        0.079698
# 3                    lh_cuneus_area        0.170902        0.550640
# 4                lh_entorhinal_area        0.307886        0.172238
# ..                              ...             ...             ...
# 65              rh_frontalpole_area        0.067719        0.167796
# 66             rh_temporalpole_area        0.977155        0.765818
# 67       rh_transversetemporal_area        0.974092        0.861242
# 68                   rh_insula_area        0.861290        0.088939
# 69            rh_WhiteSurfArea_area        0.097403        0.731343
#
#          Test used   p-value  Statistically significant
# 0   Mann-Whitney U  0.659975                      False
# 1           t-test  0.464636                      False
# 2           t-test  0.834329                      False
# 3           t-test  0.334653                      False
# 4           t-test  0.201815                      False
# ..             ...       ...                        ...
# 65          t-test  0.659891                      False
# 66          t-test  0.712581                      False
# 67          t-test  0.564377                      False
# 68          t-test  0.912071                      False
# 69          t-test  0.528915                      False
#
# [70 rows x 6 columns]

# %%
# Assuming you already have 'comparison_table' from your previous code

# Filter only statistically significant regions
significant_table = comparison_table[comparison_table['Statistically significant'] == True].copy()

# Optionally, reset the index for a clean table
significant_table = significant_table.reset_index(drop=True)

# Save to CSV
significant_table.to_csv("brain_regions_significant_comparison.csv", index=False)
print("Table saved as brain_regions_significant_comparison.csv")

# Display the table in the notebook
display(significant_table)
# Out:
# Table saved as brain_regions_significant_comparison.csv
#                      Region  Shapiro p (GW)  Shapiro p (GK)       Test used  \
# 0  lh_superiorparietal_area        0.756029        0.937848          t-test
# 1        rh_entorhinal_area        0.016749        0.343663  Mann-Whitney U
# 2       rh_paracentral_area        0.826103        0.306959          t-test
#
#     p-value  Statistically significant
# 0  0.067558                       True
# 1  0.051995                       True
# 2  0.057355                       True

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Lista de regiones significativas
significant_regions = comparison_table[comparison_table['Statistically significant'] == True]['Region'].tolist()

if significant_regions:
    # 2. Transforma df_merged a formato largo solo con regiones significativas
    df_long = df_merged.melt(
        id_vars=['Biomarkers code', 'E280A group'],
        value_vars=significant_regions,
        var_name='Brain Region',
        value_name='Area'
    )

    # 3. Gráfico de barras solo para regiones significativas
    plt.figure(figsize=(max(8, len(significant_regions)*1.2), 6))
    sns.barplot(
        data=df_long,
        x='Brain Region',
        y='Area',
        hue='E280A group',
        ci='sd'
    )
    plt.title('Group Comparison for Significant Brain Regions')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()
else:
    print("No se encontraron regiones con diferencias significativas (p < 0.01).")
# Out:
# /tmp/ipykernel_26032/2114539671.py:18: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(
